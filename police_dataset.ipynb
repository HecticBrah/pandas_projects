# %%
import pandas as pd
import numpy as np
import matplotlib as mlt

# %%
df = pd.read_csv('Downloads\police.csv')

# %%
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# 1            40.0       White                        Speeding
# 2            33.0       White                        Speeding
# 3            19.0       White                Call for Service
# 4            21.0       White                        Speeding
# ...           ...         ...                             ...
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type   stop_outcome  \
# 0              Speeding             False         NaN       Citation
# 1              Speeding             False         NaN       Citation
# 2              Speeding             False         NaN       Citation
# 3                 Other             False         NaN  Arrest Driver
# 4              Speeding             False         NaN       Citation
# ...                 ...               ...         ...            ...
# 91736          Speeding             False         NaN        Warning
# 91737         Equipment             False         NaN        Warning
# 91738  Moving violation             False         NaN        Warning
# 91739          Speeding             False         NaN       Citation
# 91740          Speeding             False         NaN       Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 0           False      0-15 Min               False
# 1           False      0-15 Min               False
# 2           False      0-15 Min               False
# 3            True     16-30 Min               False
# 4           False      0-15 Min               False
# ...           ...           ...                 ...
# 91736       False      0-15 Min               False
# 91737       False      0-15 Min               False
# 91738       False      0-15 Min               False
# 91739       False      0-15 Min               False
# 91740       False      0-15 Min               False
#
# [91741 rows x 15 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['county_name'].isnull().sum()
# Out:
# 91741

# %%
df = df.drop(columns=["county_name", "driver_age_raw"])

# %%
df
# Out:
#         stop_date stop_time driver_gender  driver_age driver_race  \
# 0      2005-01-02     01:55             M        20.0       White
# 1      2005-01-18     08:15             M        40.0       White
# 2      2005-01-23     23:15             M        33.0       White
# 3      2005-02-20     17:15             M        19.0       White
# 4      2005-03-14     10:00             F        21.0       White
# ...           ...       ...           ...         ...         ...
# 91736  2015-12-31     20:27             M        29.0       White
# 91737  2015-12-31     20:35             F        33.0       White
# 91738  2015-12-31     20:45             M        23.0       White
# 91739  2015-12-31     21:42             M        22.0       White
# 91740  2015-12-31     22:46             M        56.0    Hispanic
#
#                         violation_raw         violation  search_conducted  \
# 0                            Speeding          Speeding             False
# 1                            Speeding          Speeding             False
# 2                            Speeding          Speeding             False
# 3                    Call for Service             Other             False
# 4                            Speeding          Speeding             False
# ...                               ...               ...               ...
# 91736                        Speeding          Speeding             False
# 91737  Equipment/Inspection Violation         Equipment             False
# 91738         Other Traffic Violation  Moving violation             False
# 91739                        Speeding          Speeding             False
# 91740                        Speeding          Speeding             False
#
#       search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0             NaN       Citation       False      0-15 Min               False
# 1             NaN       Citation       False      0-15 Min               False
# 2             NaN       Citation       False      0-15 Min               False
# 3             NaN  Arrest Driver        True     16-30 Min               False
# 4             NaN       Citation       False      0-15 Min               False
# ...           ...            ...         ...           ...                 ...
# 91736         NaN        Warning       False      0-15 Min               False
# 91737         NaN        Warning       False      0-15 Min               False
# 91738         NaN        Warning       False      0-15 Min               False
# 91739         NaN       Citation       False      0-15 Min               False
# 91740         NaN       Citation       False      0-15 Min               False
#
# [91741 rows x 13 columns]

# %%
df['driver_age'].isnull().sum()
# Out:
# 5621

# %%
df.isnull().values.sum()
# Out:
# 131499

# %%
df = df.dropna()

# %%
df.head()
# Out:
#       stop_date stop_time driver_gender  driver_age driver_race  \
# 24   2005-08-28     01:00             M        26.0       White
# 40   2005-10-01     00:00             M        17.0       White
# 41   2005-10-01     00:00             M        17.0       White
# 80   2005-10-02     09:30             M        30.0       White
# 106  2005-10-03     14:00             M        27.0       Black
#
#                       violation_raw         violation  search_conducted  \
# 24          Other Traffic Violation  Moving violation              True
# 40   Equipment/Inspection Violation         Equipment              True
# 41   Equipment/Inspection Violation         Equipment              True
# 80                         Speeding          Speeding              True
# 106  Equipment/Inspection Violation         Equipment              True
#
#                              search_type   stop_outcome is_arrested  \
# 24   Incident to Arrest,Protective Frisk  Arrest Driver        True
# 40                        Probable Cause  Arrest Driver        True
# 41                        Probable Cause       Citation       False
# 80                    Incident to Arrest  Arrest Driver        True
# 106                       Probable Cause       Citation       False
#
#     stop_duration  drugs_related_stop
# 24      16-30 Min               False
# 40      16-30 Min                True
# 41        30+ Min                True
# 80        30+ Min               False
# 106     16-30 Min               False

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age driver_race  \
# 0     2005-08-28     01:00             M        26.0       White
# 1     2005-10-01     00:00             M        17.0       White
# 2     2005-10-01     00:00             M        17.0       White
# 3     2005-10-02     09:30             M        30.0       White
# 4     2005-10-03     14:00             M        27.0       Black
# ...          ...       ...           ...         ...         ...
# 3188  2015-12-18     09:30             M        49.0       White
# 3189  2015-12-21     01:39             M        29.0       White
# 3190  2015-12-28     11:05             F        19.0       White
# 3191  2015-12-30     08:51             F        28.0    Hispanic
# 3192  2015-12-30     13:15             M        23.0       White
#
#                        violation_raw            violation  search_conducted  \
# 0            Other Traffic Violation     Moving violation              True
# 1     Equipment/Inspection Violation            Equipment              True
# 2     Equipment/Inspection Violation            Equipment              True
# 3                           Speeding             Speeding              True
# 4     Equipment/Inspection Violation            Equipment              True
# ...                              ...                  ...               ...
# 3188          Registration Violation  Registration/plates              True
# 3189         Other Traffic Violation     Moving violation              True
# 3190                             APB                Other              True
# 3191                        Speeding             Speeding              True
# 3192              Seatbelt Violation            Seat belt              True
#
#                               search_type      stop_outcome is_arrested  \
# 0     Incident to Arrest,Protective Frisk     Arrest Driver        True
# 1                          Probable Cause     Arrest Driver        True
# 2                          Probable Cause          Citation       False
# 3                      Incident to Arrest     Arrest Driver        True
# 4                          Probable Cause          Citation       False
# ...                                   ...               ...         ...
# 3188                   Incident to Arrest         No Action       False
# 3189                   Incident to Arrest          Citation       False
# 3190                   Incident to Arrest          Citation       False
# 3191  Probable Cause,Reasonable Suspicion          Citation       False
# 3192                   Incident to Arrest  Arrest Passenger        True
#
#      stop_duration  drugs_related_stop
# 0        16-30 Min               False
# 1        16-30 Min                True
# 2          30+ Min                True
# 3          30+ Min               False
# 4        16-30 Min               False
# ...            ...                 ...
# 3188     16-30 Min               False
# 3189      0-15 Min               False
# 3190     16-30 Min                True
# 3191       30+ Min                True
# 3192     16-30 Min               False
#
# [3193 rows x 13 columns]

# %%
df.driver_race.value_counts()
# Out:
# White       1766
# Black        789
# Hispanic     584
# Asian         51
# Other          3
# Name: driver_race, dtype: int64

# %%
df.driver_race.value_counts().plot(kind="barh", color="lime", edgecolor = "black")
# Out:
# <AxesSubplot:>

# %%
df.driver_gender.value_counts()
# Out:
# M    2722
# F     471
# Name: driver_gender, dtype: int64

# %%
df_other = df.loc[df['driver_race']=='Other']

# %%
df_other
# Out:
#        stop_date stop_time driver_gender  driver_age driver_race  \
# 1430  2009-07-31     13:41             M        44.0       Other
# 2872  2014-07-29     19:56             M        23.0       Other
# 3147  2015-09-16     14:20             M        41.0       Other
#
#                 violation_raw            violation  search_conducted  \
# 1430   Registration Violation  Registration/plates              True
# 2872       Seatbelt Violation            Seat belt              True
# 3147  Other Traffic Violation     Moving violation              True
#
#              search_type      stop_outcome is_arrested stop_duration  \
# 1430  Incident to Arrest  Arrest Passenger        True     16-30 Min
# 2872      Probable Cause          Citation       False       30+ Min
# 3147           Inventory          Citation       False       30+ Min
#
#       drugs_related_stop
# 1430               False
# 2872                True
# 3147               False

# %%
df['driver_age'] = df['driver_age'].astype(int)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age driver_race  \
# 0     2005-08-28     01:00             M          26       White
# 1     2005-10-01     00:00             M          17       White
# 2     2005-10-01     00:00             M          17       White
# 3     2005-10-02     09:30             M          30       White
# 4     2005-10-03     14:00             M          27       Black
# ...          ...       ...           ...         ...         ...
# 3188  2015-12-18     09:30             M          49       White
# 3189  2015-12-21     01:39             M          29       White
# 3190  2015-12-28     11:05             F          19       White
# 3191  2015-12-30     08:51             F          28    Hispanic
# 3192  2015-12-30     13:15             M          23       White
#
#                        violation_raw            violation  search_conducted  \
# 0            Other Traffic Violation     Moving violation              True
# 1     Equipment/Inspection Violation            Equipment              True
# 2     Equipment/Inspection Violation            Equipment              True
# 3                           Speeding             Speeding              True
# 4     Equipment/Inspection Violation            Equipment              True
# ...                              ...                  ...               ...
# 3188          Registration Violation  Registration/plates              True
# 3189         Other Traffic Violation     Moving violation              True
# 3190                             APB                Other              True
# 3191                        Speeding             Speeding              True
# 3192              Seatbelt Violation            Seat belt              True
#
#                               search_type      stop_outcome is_arrested  \
# 0     Incident to Arrest,Protective Frisk     Arrest Driver        True
# 1                          Probable Cause     Arrest Driver        True
# 2                          Probable Cause          Citation       False
# 3                      Incident to Arrest     Arrest Driver        True
# 4                          Probable Cause          Citation       False
# ...                                   ...               ...         ...
# 3188                   Incident to Arrest         No Action       False
# 3189                   Incident to Arrest          Citation       False
# 3190                   Incident to Arrest          Citation       False
# 3191  Probable Cause,Reasonable Suspicion          Citation       False
# 3192                   Incident to Arrest  Arrest Passenger        True
#
#      stop_duration  drugs_related_stop
# 0        16-30 Min               False
# 1        16-30 Min                True
# 2          30+ Min                True
# 3          30+ Min               False
# 4        16-30 Min               False
# ...            ...                 ...
# 3188     16-30 Min               False
# 3189      0-15 Min               False
# 3190     16-30 Min                True
# 3191       30+ Min                True
# 3192     16-30 Min               False
#
# [3193 rows x 13 columns]

# %%
replace_dict = {'search_conducted' : { True : 'Yes', False : 'No' },
           'is_arrested' : { True : 'Yes', False : 'No' },
           'drugs_related_stop' : { True : 'Yes', False : 'No' }}

# %%
df.replace(replace_dict, inplace=True)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age driver_race  \
# 0     2005-08-28     01:00             M          26       White
# 1     2005-10-01     00:00             M          17       White
# 2     2005-10-01     00:00             M          17       White
# 3     2005-10-02     09:30             M          30       White
# 4     2005-10-03     14:00             M          27       Black
# ...          ...       ...           ...         ...         ...
# 3188  2015-12-18     09:30             M          49       White
# 3189  2015-12-21     01:39             M          29       White
# 3190  2015-12-28     11:05             F          19       White
# 3191  2015-12-30     08:51             F          28    Hispanic
# 3192  2015-12-30     13:15             M          23       White
#
#                        violation_raw            violation search_conducted  \
# 0            Other Traffic Violation     Moving violation              Yes
# 1     Equipment/Inspection Violation            Equipment              Yes
# 2     Equipment/Inspection Violation            Equipment              Yes
# 3                           Speeding             Speeding              Yes
# 4     Equipment/Inspection Violation            Equipment              Yes
# ...                              ...                  ...              ...
# 3188          Registration Violation  Registration/plates              Yes
# 3189         Other Traffic Violation     Moving violation              Yes
# 3190                             APB                Other              Yes
# 3191                        Speeding             Speeding              Yes
# 3192              Seatbelt Violation            Seat belt              Yes
#
#                               search_type      stop_outcome is_arrested  \
# 0     Incident to Arrest,Protective Frisk     Arrest Driver         Yes
# 1                          Probable Cause     Arrest Driver         Yes
# 2                          Probable Cause          Citation          No
# 3                      Incident to Arrest     Arrest Driver         Yes
# 4                          Probable Cause          Citation          No
# ...                                   ...               ...         ...
# 3188                   Incident to Arrest         No Action          No
# 3189                   Incident to Arrest          Citation          No
# 3190                   Incident to Arrest          Citation          No
# 3191  Probable Cause,Reasonable Suspicion          Citation          No
# 3192                   Incident to Arrest  Arrest Passenger         Yes
#
#      stop_duration drugs_related_stop
# 0        16-30 Min                 No
# 1        16-30 Min                Yes
# 2          30+ Min                Yes
# 3          30+ Min                 No
# 4        16-30 Min                 No
# ...            ...                ...
# 3188     16-30 Min                 No
# 3189      0-15 Min                 No
# 3190     16-30 Min                Yes
# 3191       30+ Min                Yes
# 3192     16-30 Min                 No
#
# [3193 rows x 13 columns]
